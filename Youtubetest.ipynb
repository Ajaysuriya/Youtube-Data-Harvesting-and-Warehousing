# %%
from googleapiclient.discovery import build
import pymongo
import mysql.connector
import pandas as pd
import streamlit as st

# %%
AIzaSyB6La9IEwHmMvi1UGq4kCiYHOl0u68Wq44

# %%
def Api_connect():
    Api_Id="AIzaSyB6La9IEwHmMvi1UGq4kCiYHOl0u68Wq44"

    Api_service_name="youtube"
    Api_version="v3"

    youtube=build(Api_service_name,Api_version,developerKey=Api_Id)
    return youtube

# %%
youtube=Api_connect()

# %%
request=youtube.channels().list(
    part="snippet,contentDetails,Statistics",
    id="UCX6OQ3DkcsbYNE6H8uQQuVA"
)
response=request.execute()

# %%
print(len(response))
# Out:
# 4

# %%
b=response
print(b)
c=list(response)
print(c)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '1JODjD0tjFASLsmIQSzTRdQnoaY', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'oBwRMTJVbIde3sd9BOgts__STik', 'id': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'snippet': {'title': 'MrBeast', 'description': "SUBSCRIBE FOR A COOKIE!\nAccomplishments:\n- Raised $20,000,000 To Plant 20,000,000 Trees\n- Removed 30,000,000 pounds of trash from the ocean\n- Built wells in Africa\n- helped 1,000 blind people see\n- helped 1,000 deaf people hear\n- Given millions to charity\n- Started my own snack company Feastables\n- Donated over 100 cars lol\n- Gave away a private island (twice)\n- Gave away 1 million dollars in one video\n- Counted to 100k\n- Read the Dictionary\n- Read Bee Movie Script\n- Read Longest English Word\n- Watched Paint Dry\n- Ubering Across America\n- Watched It's Every Day Bro For 10 Hours\n- Ran a marathon in the world's largest shoes\n- Adopted every dog in a shelter\n- Bought $1,000,000 in lottery tickets\n- Sold houses for $1\n- I got buried alive\n- Recreated Squid Game in real life\n- Gave away a chocolate factory\n- Gave away private jet\n- Survived 50 hours in Antarctica\nYou get the point haha\n\n\n*Do not email me asking for money, I give away money because it makes me happy :)", 'customUrl': '@mrbeast', 'publishedAt': '2012-02-20T00:43:50Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'MrBeast', 'description': "SUBSCRIBE FOR A COOKIE!\nAccomplishments:\n- Raised $20,000,000 To Plant 20,000,000 Trees\n- Removed 30,000,000 pounds of trash from the ocean\n- Built wells in Africa\n- helped 1,000 blind people see\n- helped 1,000 deaf people hear\n- Given millions to charity\n- Started my own snack company Feastables\n- Donated over 100 cars lol\n- Gave away a private island (twice)\n- Gave away 1 million dollars in one video\n- Counted to 100k\n- Read the Dictionary\n- Read Bee Movie Script\n- Read Longest English Word\n- Watched Paint Dry\n- Ubering Across America\n- Watched It's Every Day Bro For 10 Hours\n- Ran a marathon in the world's largest shoes\n- Adopted every dog in a shelter\n- Bought $1,000,000 in lottery tickets\n- Sold houses for $1\n- I got buried alive\n- Recreated Squid Game in real life\n- Gave away a chocolate factory\n- Gave away private jet\n- Survived 50 hours in Antarctica\nYou get the point haha\n\n\n*Do not email me asking for money, I give away money because it makes me happy :)"}, 'country': 'US'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUX6OQ3DkcsbYNE6H8uQQuVA'}}, 'statistics': {'viewCount': '41485846757', 'subscriberCount': '232000000', 'hiddenSubscriberCount': False, 'videoCount': '774'}}]}
# ['kind', 'etag', 'pageInfo', 'items']

# %%
a=list(response['items'])

# %%
print(a)
# Out:
# [{'kind': 'youtube#channel', 'etag': 'oBwRMTJVbIde3sd9BOgts__STik', 'id': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'snippet': {'title': 'MrBeast', 'description': "SUBSCRIBE FOR A COOKIE!\nAccomplishments:\n- Raised $20,000,000 To Plant 20,000,000 Trees\n- Removed 30,000,000 pounds of trash from the ocean\n- Built wells in Africa\n- helped 1,000 blind people see\n- helped 1,000 deaf people hear\n- Given millions to charity\n- Started my own snack company Feastables\n- Donated over 100 cars lol\n- Gave away a private island (twice)\n- Gave away 1 million dollars in one video\n- Counted to 100k\n- Read the Dictionary\n- Read Bee Movie Script\n- Read Longest English Word\n- Watched Paint Dry\n- Ubering Across America\n- Watched It's Every Day Bro For 10 Hours\n- Ran a marathon in the world's largest shoes\n- Adopted every dog in a shelter\n- Bought $1,000,000 in lottery tickets\n- Sold houses for $1\n- I got buried alive\n- Recreated Squid Game in real life\n- Gave away a chocolate factory\n- Gave away private jet\n- Survived 50 hours in Antarctica\nYou get the point haha\n\n\n*Do not email me asking for money, I give away money because it makes me happy :)", 'customUrl': '@mrbeast', 'publishedAt': '2012-02-20T00:43:50Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZTM49hEx9zyui_0zDZKi75EgqJPJfuDmWu1cePdQQ=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'MrBeast', 'description': "SUBSCRIBE FOR A COOKIE!\nAccomplishments:\n- Raised $20,000,000 To Plant 20,000,000 Trees\n- Removed 30,000,000 pounds of trash from the ocean\n- Built wells in Africa\n- helped 1,000 blind people see\n- helped 1,000 deaf people hear\n- Given millions to charity\n- Started my own snack company Feastables\n- Donated over 100 cars lol\n- Gave away a private island (twice)\n- Gave away 1 million dollars in one video\n- Counted to 100k\n- Read the Dictionary\n- Read Bee Movie Script\n- Read Longest English Word\n- Watched Paint Dry\n- Ubering Across America\n- Watched It's Every Day Bro For 10 Hours\n- Ran a marathon in the world's largest shoes\n- Adopted every dog in a shelter\n- Bought $1,000,000 in lottery tickets\n- Sold houses for $1\n- I got buried alive\n- Recreated Squid Game in real life\n- Gave away a chocolate factory\n- Gave away private jet\n- Survived 50 hours in Antarctica\nYou get the point haha\n\n\n*Do not email me asking for money, I give away money because it makes me happy :)"}, 'country': 'US'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUX6OQ3DkcsbYNE6H8uQQuVA'}}, 'statistics': {'viewCount': '41485846757', 'subscriberCount': '232000000', 'hiddenSubscriberCount': False, 'videoCount': '774'}}]

# %%
def get_channel_info(channel_id):
    request=youtube.channels().list(
        part="snippet,contentDetails,Statistics",
        id=channel_id
    )
    response=request.execute()

    for i in range(0,len(response['items'])):
        data=dict(Channel_Name=response['items'][i]['snippet']['title'],
                  Channel_Id=response['items'][i]['id'],
                  Subscription_Count=response['items'][i]['statistics']['subscriberCount'],
                  Views=response['items'][i]['statistics']['viewCount'],
                  Total_Videos=response['items'][i]['statistics']['videoCount'],
                  Channel_Description=response['items'][i]['snippet']['description'],
                  Playlist_Id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
    return data

# %%
g=get_channel_info("UCueYcgdqos0_PzNOq81zAFg")

print(g)
# Out:
# {'Channel_Name': 'Parithabangal', 'Channel_Id': 'UCueYcgdqos0_PzNOq81zAFg', 'Subscription_Count': '5300000', 'Views': '1251753047', 'Total_Videos': '723', 'Channel_Description': 'Welcome to Parithabangal - your perfect fun stop with unlimited entertainment ranging from all age groups.\n\nScroll down to watch our best comedy sketches that can bring you chuckles. All the funny videos are made to make you laugh, covering trending topics.\n\nSubscribe to our official channel and never miss watching our latest videos.\n\n**********************\n\nOur Digital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n\n**********************\n', 'Playlist_Id': 'UUueYcgdqos0_PzNOq81zAFg'}

# %%
def get_videos_ids(channel_id):
    video_ids=[]

    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    
    Playlist_Id=response['items'][0][ 'contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None
    while True:
        response1=youtube.playlistItems().list(
                                        part='snippet',
                                        playlistId=Playlist_Id,
                                        maxResults=50,
                                        pageToken=next_page_token).execute()
        for i in range(len(response1["items"])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')
        if next_page_token==None:
            break
    return video_ids

# %%
video_ids=get_videos_ids('UCueYcgdqos0_PzNOq81zAFg')

# %%
video_ids[13]
# Out:
# 'C4looAr9vx4'

# %%
Video_ids=get_videos_ids('UCp8lSYM0V3KB3mAr_9DV8Sg')

# %%
response = youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id="sw9BVKR9zDQ"
        ).execute()

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#playlist',
#  'etag': 'R8EJIUCzB63eeMVppIvLFi4p-KM',
#  'id': 'PLeEP84ImH_Lvi2x7jygwDJpPmalzMk6pi',
#  'snippet': {'publishedAt': '2024-01-12T12:00:01Z',
#   'channelId': 'UCY6KjrDBN_tIRFT_QNqQbRQ',
#   'title': 'Movies X Madan Gowri',
#   'description': '',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A1LVkmTn0-c/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/A1LVkmTn0-c/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/A1LVkmTn0-c/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/A1LVkmTn0-c/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/A1LVkmTn0-c/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'Madan Gowri',
#   'localized': {'title': 'Movies X Madan Gowri', 'description': ''}},
#  'contentDetails': {'itemCount': 18}}

# %%
def get_videos_info(Video_ids):
    video_data=[]
    for video_id in Video_ids:
        response = youtube.videos().list(
                part="snippet,ContentDetails,statistics",
                id=video_id
            ).execute()
        for items in response["items"]:
            
            data=dict( 
                    Channel_Name = items['snippet']['channelTitle'],
                    Channel_Id = items['snippet']['channelId'],
                    Video_Id = items['id'],
                    Title =items['snippet']['title'],
                    Tags =items['snippet'].get('tags'),
                    Thumbnail =items['snippet']['thumbnails']['default']['url'],
                    Description = items['snippet'].get('description'),
                    Published_Date =items['snippet']['publishedAt'],
                    Duration =items['contentDetails']['duration'],
                    Views =items['statistics'].get('viewCount'),
                    Likes =items['statistics'].get('likeCount'),
                    Comments = items['statistics'].get('commentCount'),
                    Favorite_Count =items['statistics']['favoriteCount'],
                    Definition =items['contentDetails']['definition'],
                    Caption_Status =items['contentDetails']['caption'] 
            )
            video_data.append(data)
    return video_data

# %%
video_details= get_videos_info(Video_ids)

# %%
len(video_details)
# Out:
# 95

# %%
video_details[0]
# Out:
# {'Channel_Name': 'Nifya Furniture',
#  'Channel_Id': 'UCp8lSYM0V3KB3mAr_9DV8Sg',
#  'Video_Id': 'shtXOmYiuGk',
#  'Title': 'Nifya Furniture...#shorts',
#  'Tags': None,
#  'Thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/shtXOmYiuGk/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/shtXOmYiuGk/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/shtXOmYiuGk/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/shtXOmYiuGk/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/shtXOmYiuGk/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'Description': 'Shop Address :\n\n17,1st Street , East abiramapuram,Mylapore,Chennai,\nTamil nadu PinCode-600004.\nMobile Number: 8778982825, 7550194119\nLocation: https://maps.google.com/maps?q=13.034...',
#  'Published_Date': '2024-01-23T11:27:06Z',
#  'Duration': 'PT30S',
#  'Views': '513742',
#  'Likes': '45406',
#  'Comments': '444',
#  'Favorite_Count': '0',
#  'Definition': 'hd',
#  'Caption_Status': 'false'}

# %%
def get_Comment_Information(Video_ids):
    Comment_Information=[]
    try:
        for video_ids in Video_ids:
            response=youtube.commentThreads().list(
                part='snippet',
                videoId=video_ids,
                maxResults=100).execute()

            for items in response['items']:
                data=dict(Comment_Id= items['snippet']['topLevelComment']['id'],
                        Video_Id= items['snippet']['videoId'],
                        Comment_Text= items['snippet']['topLevelComment']['snippet']['textOriginal'],
                        Comment_Author= items ['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published= items ['snippet']['topLevelComment']['snippet']['publishedAt']
                        )
                Comment_Information.append(data)
    except:
        pass

    return Comment_Information

# %%
Comment_data= get_Comment_Information(Video_ids)

# %%
Comment_data
# Out:
# [{'Comment_Id': 'UgygMVLvGST4mMCrxs14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super tampi all the best',
#   'Comment_Author': '@user-cr8ld3zk4e',
#   'Comment_Published': '2024-01-26T13:55:55Z'},
#  {'Comment_Id': 'UgxZsQKztMHkJ1VzIVZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Veetla cartoon paathutu \nSuthura kids ivankitta modakku modakku edhana 😂😂😂',
#   'Comment_Author': '@dayatec',
#   'Comment_Published': '2024-01-26T13:55:16Z'},
#  {'Comment_Id': 'Ugyv5KQrQnuTkJ2AuRF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thambi entha negative comments ahyum mind pannaatha❤❤❤❤❤❤go for it kanna❤❤❤❤❤❤❤',
#   'Comment_Author': '@user-iq6rn3gt3i',
#   'Comment_Published': '2024-01-26T13:49:41Z'},
#  {'Comment_Id': 'Ugw904TKnLvVEKL6roV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Walthukkal da chellam',
#   'Comment_Author': '@abiprabu6808',
#   'Comment_Published': '2024-01-26T13:36:32Z'},
#  {'Comment_Id': 'UgwcNKSuBtC64nUXYhB4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'thambi velichama iruku night 12.30 solraa',
#   'Comment_Author': '@rajendranm8984',
#   'Comment_Published': '2024-01-26T13:02:42Z'},
#  {'Comment_Id': 'UgyoaXsXzMYvJiNE0o54AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Nadi narumballam sofa than',
#   'Comment_Author': '@user-yo9ev2kq1m',
#   'Comment_Published': '2024-01-26T12:26:13Z'},
#  {'Comment_Id': 'UgzdhFAuP9iOd4m7U_t4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Stay positive thambi......u will win👍👍👍👍',
#   'Comment_Author': '@kraftrealistic6124',
#   'Comment_Published': '2024-01-26T12:22:10Z'},
#  {'Comment_Id': 'Ugwj8oM5PIt3TH7j2kd4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'All d best ❤❤',
#   'Comment_Author': '@kraftrealistic6124',
#   'Comment_Published': '2024-01-26T12:21:16Z'},
#  {'Comment_Id': 'UgzJEg-AjBNDbwneD2Z4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Vellore ku delivery kudupingala',
#   'Comment_Author': '@akhiladelhi',
#   'Comment_Published': '2024-01-26T11:32:33Z'},
#  {'Comment_Id': 'UgyWboJz66KxnG3fjDR4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super',
#   'Comment_Author': '@kajan.',
#   'Comment_Published': '2024-01-26T11:07:31Z'},
#  {'Comment_Id': 'UgzZBNtegh7Ii2JJk794AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Da neya sopa mari than da eruka😂😂😂😂',
#   'Comment_Author': '@pubgcreators4645',
#   'Comment_Published': '2024-01-26T10:47:50Z'},
#  {'Comment_Id': 'UgzzWsDphzmZq0CbvtF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '😅😅😅😅😅',
#   'Comment_Author': '@aravindmathew2209',
#   'Comment_Published': '2024-01-26T10:27:37Z'},
#  {'Comment_Id': 'UgyYibWPlXBLFqnEOgx4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'டேய் தம்பி நீ போடுற வீடியோ பார்த்து எல்லாம் பசங்களும் படிக்காமல் இதே போல வீடியோ பார்த்து கெட்டுப் போக போறாங்க. உங்க அப்பா பிசினஸ் வச்சிருக்காரு பிசினஸ் வச்சுக்காதப்பா எல்லாம் என்னடா பண்ணுவான் மாத சம்பளம் தாண்டா\n\n இந்த பெற்றோரே தயவு செய்து நீங்கள் வியாபாரம் செய்யுங்கள் இதுபோல் குழந்தைகளை வியாபாரம் செய்ய விடாதீர்கள் இது ஒரு கல்வி வளர்ச்சிக்கு எல்லா பிள்ளைகளுக்கும் ஒரு பின் உதாரணமாக இருக்கும் முன்னுதாரணமாக இருக்காது புரிந்து கொள்ளுங்கள்',
#   'Comment_Author': '@loganathanvenkat8439',
#   'Comment_Published': '2024-01-26T10:21:30Z'},
#  {'Comment_Id': 'UgyNYsppcvuglnK_2il4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super da thambi❤',
#   'Comment_Author': '@fathimafarshana5286',
#   'Comment_Published': '2024-01-26T10:11:27Z'},
#  {'Comment_Id': 'Ugz33WRBqTlGFRieujZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Vandalur bus stand la meet pannomla',
#   'Comment_Author': '@saravanans4581',
#   'Comment_Published': '2024-01-26T09:56:47Z'},
#  {'Comment_Id': 'UgzLsXYZGGy_8APbKSN4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Dai Kai enda Kanda edathuku pothu😂😂',
#   'Comment_Author': '@rsjoker2221',
#   'Comment_Published': '2024-01-26T09:56:33Z'},
#  {'Comment_Id': 'UgyFsTzjsybmhIIOxX14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Hiiii bro yepdi irukinga',
#   'Comment_Author': '@saravanans4581',
#   'Comment_Published': '2024-01-26T09:56:26Z'},
#  {'Comment_Id': 'UgxEe_7Unh3e7jAWwrN4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sofa das😂',
#   'Comment_Author': '@sachinc8101',
#   'Comment_Published': '2024-01-26T09:28:50Z'},
#  {'Comment_Id': 'Ugz2bS1imRxYvEe_HJV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Appaa vela seiraaru sari kannaa neeyum vela seiriye.. adhu thaan highlight😅',
#   'Comment_Author': '@PeterX-dh5xs',
#   'Comment_Published': '2024-01-26T09:22:50Z'},
#  {'Comment_Id': 'UgwCDBz3cEkGyLuLsAV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super da',
#   'Comment_Author': '@user-ru2sr4qd9n',
#   'Comment_Published': '2024-01-26T09:06:42Z'},
#  {'Comment_Id': 'UgwDEBwgncSlyAgHxsV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Udal mannuku uyire sofa ku',
#   'Comment_Author': '@user-in3nx6wm2p',
#   'Comment_Published': '2024-01-26T09:03:38Z'},
#  {'Comment_Id': 'UgzBIvjLmKmcr1u12P14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thambi ne periya all ah varuva ❤',
#   'Comment_Author': '@raaghulvibes8856',
#   'Comment_Published': '2024-01-26T08:58:15Z'},
#  {'Comment_Id': 'UgzjvP6Sj7Bslwt1pfx4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Poda pund😂',
#   'Comment_Author': '@karanashwanth-bq8kf',
#   'Comment_Published': '2024-01-26T08:57:53Z'},
#  {'Comment_Id': 'UgxKAEFVRPtVi9P_lCB4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'I am ur big fan ❤🎉',
#   'Comment_Author': '@user-ft3mn2rk2v',
#   'Comment_Published': '2024-01-26T08:53:03Z'},
#  {'Comment_Id': 'UgxnWEsMim21ibx2cqh4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'How cute. God bless you 😊',
#   'Comment_Author': '@DrMonica21',
#   'Comment_Published': '2024-01-26T08:29:25Z'},
#  {'Comment_Id': 'Ugwb2OQfCryvuboxfvN4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'I m your fan. You are super kid \nGod bless you',
#   'Comment_Author': '@raghavendras5737',
#   'Comment_Published': '2024-01-26T08:09:25Z'},
#  {'Comment_Id': 'UgzeruP2yfSc7S7p79d4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sofa boy',
#   'Comment_Author': '@roritobanz4275',
#   'Comment_Published': '2024-01-26T08:08:09Z'},
#  {'Comment_Id': 'Ugy4lH7erVxbvG02pP14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Business blood ❤',
#   'Comment_Author': '@kavishi8625',
#   'Comment_Published': '2024-01-26T07:55:59Z'},
#  {'Comment_Id': 'UgxFLAQ6NHe-2hA_yQV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '❤',
#   'Comment_Author': '@pandiyanmuthukaruppaiah4291',
#   'Comment_Published': '2024-01-26T07:34:30Z'},
#  {'Comment_Id': 'UgzP4k9PgTRWHpaH0m54AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'குண்டு பயபுள்ள ❤️👍',
#   'Comment_Author': '@balajim6145',
#   'Comment_Published': '2024-01-26T07:30:39Z'},
#  {'Comment_Id': 'UgwAmoyaL_ku5WgMOLB4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Dai Gunda',
#   'Comment_Author': '@manigandans5576',
#   'Comment_Published': '2024-01-26T07:28:35Z'},
#  {'Comment_Id': 'Ugwvn1C0ly2FVwKvdmZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'You are good chellam, keep going, all the best 🎉',
#   'Comment_Author': '@chesseverything8104',
#   'Comment_Published': '2024-01-26T07:12:01Z'},
#  {'Comment_Id': 'Ugzqb_7mfqQJlKTGNft4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thambi ni yaru kittaum manipu keka vendiya avadiyamae illa ni indha vayasula unga appa ku help pananu nu nenaikura but vela Ilama una vandhu kora soldravanga unna thitradhu madhippu illadhadhu ni niya iru idhu un youtube channel ni unakaga olaikura yaru una ena sonnalu kadhula vangikadha ni pandradha panu pa all the best for your future ni migjam puyal pathi pesi video poturundha aprm adhukaga mannipu keturundha ana andha video la ni comments off panirundha adhunala tha na indha video la comment panna....do your best thambi ❤',
#   'Comment_Author': '@kalaikalaiselvi4108',
#   'Comment_Published': '2024-01-26T07:12:01Z'},
#  {'Comment_Id': 'UgyPRV6nsgEfoQTOA6R4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super da Thambi\nNegative comments lam mind la yethadhey\nNe future la semma businesses man a varuva pa\nAppaku perumai serpadharku vazhthukal 💐',
#   'Comment_Author': '@radhachandru-1991',
#   'Comment_Published': '2024-01-26T06:54:59Z'},
#  {'Comment_Id': 'UgxNN-FzDsYAi8hlozt4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sunni poi padi parama  padida dai',
#   'Comment_Author': '@ragunath4074',
#   'Comment_Published': '2024-01-26T06:41:08Z'},
#  {'Comment_Id': 'Ugw2Ft75sk6usvEg-Ox4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Unga appa ennana 10 peru velaki vachirukendraru nee ennana ipdi solra ore kolappama iruku saami',
#   'Comment_Author': '@user-co2wh6ew9n',
#   'Comment_Published': '2024-01-26T06:28:34Z'},
#  {'Comment_Id': 'UgxcriD4fQKIkGrmVjB4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Bro negative coment varum adhalam kandukadhinga ok',
#   'Comment_Author': '@ArunKumar-rm4xg',
#   'Comment_Published': '2024-01-26T05:43:29Z'},
#  {'Comment_Id': 'UgzrMHa2nv1Cvi_aiRp4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': "This boy only showing for YouTube to  develop he's company and for me Worst place ever . Too hyped . The owner never delivers anything on time . I was behind them for a single cost for almost a week, there was no response from them and was very rude . I highly do not recommend this place to anyone . Be it a single cot or be it a L shaped sofa or whatever , pls go to some reputed furniture store . Do not waste time with these please",
#   'Comment_Author': '@akshitrdesai7698',
#   'Comment_Published': '2024-01-26T05:27:57Z'},
#  {'Comment_Id': 'UgztlZA3V2C79kVgtPV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Cella pathu nasamagaum pigalam, una Mari nallaum varalam. Nalla padi da thambi padipa vitratha. Soper boy',
#   'Comment_Author': '@saravananapk439',
#   'Comment_Published': '2024-01-26T05:14:27Z'},
#  {'Comment_Id': 'UgxHnq7NPIikze0N2TF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'God bless u dear',
#   'Comment_Author': '@dr.m.hemapaulbenjamin9781',
#   'Comment_Published': '2024-01-26T05:11:30Z'},
#  {'Comment_Id': 'UgxB5twGyQxJWnUGi9h4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Kutty kunjan ❎ sofa kunjan ✅',
#   'Comment_Author': '@AkashReddy420',
#   'Comment_Published': '2024-01-26T04:30:00Z'},
#  {'Comment_Id': 'UgzU__0z-7wX0v6IVu14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Kutty kunja ❎ Sofa kunjan ✅',
#   'Comment_Author': '@AkashReddy420',
#   'Comment_Published': '2024-01-26T04:29:05Z'},
#  {'Comment_Id': 'UgwS5KWfk-d3_UbbwyR4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Good  Job',
#   'Comment_Author': '@harishselvaraj02',
#   'Comment_Published': '2024-01-26T04:20:15Z'},
#  {'Comment_Id': 'UgzNj6jJ0l5lp5D7x714AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super da🎉❤',
#   'Comment_Author': '@subbubala14390',
#   'Comment_Published': '2024-01-26T04:19:15Z'},
#  {'Comment_Id': 'Ugxk4IjfHjJzcuIFw6x4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Nanum night 12 hrs duty  pakuren..',
#   'Comment_Author': '@Abcd-zk5so',
#   'Comment_Published': '2024-01-26T04:10:41Z'},
#  {'Comment_Id': 'Ugwpvv9ppiZ23Vy43Vl4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Ne Ila na unga appa best price ku 500 rs ku thatuvaru',
#   'Comment_Author': '@prakashv1000',
#   'Comment_Published': '2024-01-26T04:06:56Z'},
#  {'Comment_Id': 'Ugymj6gqMmNDyNEPLE94AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Dai sofa. Sofa la thermocol vachu pack panringa etha unga quality ah da 😂😂😂😂😂',
#   'Comment_Author': '@prakashv1000',
#   'Comment_Published': '2024-01-26T04:06:01Z'},
#  {'Comment_Id': 'Ugy7C1LyRKafB-SpWPV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'தம்பி கோவையில்  விரைவில் கடை திறக்க வேண்டும் ❤',
#   'Comment_Author': '@user-sy7fb3lh3f',
#   'Comment_Published': '2024-01-26T04:03:17Z'},
#  {'Comment_Id': 'UgxmM3weXoVLlsxZYON4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Full video podu thampi.... Unakkum useful ah irukkum... Engalukkum happy ah irukkum❤',
#   'Comment_Author': '@JasCinecafe',
#   'Comment_Published': '2024-01-26T03:59:41Z'},
#  {'Comment_Id': 'UgwcVmKnjR0sGIe5zDV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Idhanala dhaan ungaluku best price la thara mudiyudhu 😂🤣',
#   'Comment_Author': '@hraja2791',
#   'Comment_Published': '2024-01-26T03:12:18Z'},
#  {'Comment_Id': 'UgyuT5GlzzzGbmeogKJ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Bangalore anupu mudiuma ?',
#   'Comment_Author': '@asokan7298',
#   'Comment_Published': '2024-01-26T03:11:38Z'},
#  {'Comment_Id': 'UgxdQJ0_TjMeAodlndp4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Kadaisiya onnu sonniga....enaku thappa ketudhu...Etho honest ku August sonna mathiri iruthu chi...😅',
#   'Comment_Author': '@aashikahamed3400',
#   'Comment_Published': '2024-01-26T03:03:21Z'},
#  {'Comment_Id': 'UgyqJBKoSdBNdHt2gql4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Dei thanga katti yaaru da nee 😂😂 ayo ayo super da thangam.. all the best !!',
#   'Comment_Author': '@jayzmatt6670',
#   'Comment_Published': '2024-01-26T02:56:19Z'},
#  {'Comment_Id': 'Ugw6h5ZSRN_uHBShkdt4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'I need a kid sofa , dear child. Called u ....',
#   'Comment_Author': '@kokilamurugan7505',
#   'Comment_Published': '2024-01-26T02:50:53Z'},
#  {'Comment_Id': 'UgxzjJu4JppiH-9plkh4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sofa Sofa Sofa....😂',
#   'Comment_Author': '@user-bu8bv7sg5k',
#   'Comment_Published': '2024-01-26T02:38:43Z'},
#  {'Comment_Id': 'UgyJ40ZkmYd5cCpgt9J4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'This is good❤',
#   'Comment_Author': '@saravananabi1826',
#   'Comment_Published': '2024-01-26T02:31:31Z'},
#  {'Comment_Id': 'Ugw676fa-g7RWz0v4E14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Dae gommalaka',
#   'Comment_Author': '@diokarthik8554',
#   'Comment_Published': '2024-01-26T02:18:55Z'},
#  {'Comment_Id': 'Ugz5wZyane0hkXRTVt14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'நான் இந்த கடைக்கு போய் இருக்கேன் இவங்க சொல்றது ஒன்னும் அங்க செய்யறது ஒன்னு',
#   'Comment_Author': '@rojaramesh1927',
#   'Comment_Published': '2024-01-26T02:05:16Z'},
#  {'Comment_Id': 'UgykTDvoCH9y30dhiAV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'வருங்கால அம்பானி..🔥🔥',
#   'Comment_Author': '@masterpiece288',
#   'Comment_Published': '2024-01-26T01:58:21Z'},
#  {'Comment_Id': 'Ugz6P5VaL3UPp4vmtOR4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Best price best speech da',
#   'Comment_Author': '@user-hh8yk4bg2j',
#   'Comment_Published': '2024-01-26T00:49:38Z'},
#  {'Comment_Id': 'UgwtUef7dRhuQkkcgoV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': "I don't live in India, but I want to buy his sofa",
#   'Comment_Author': '@m.e.zz.e.m6546',
#   'Comment_Published': '2024-01-26T00:07:50Z'},
#  {'Comment_Id': 'UgxurOJCqctHWvB4LqZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Suparepw baby',
#   'Comment_Author': '@valdemarchocolate390',
#   'Comment_Published': '2024-01-25T22:05:51Z'},
#  {'Comment_Id': 'UgxGGbnVb_uwgTT7EyF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'டேய், நீ honesty யா... \nQuality not good',
#   'Comment_Author': '@user-ou7yg4cn4w',
#   'Comment_Published': '2024-01-25T21:43:22Z'},
#  {'Comment_Id': 'UgyAo_67E_YRFlQxKeB4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Aanga kadaila ship pa eirku  kufiya furnicher',
#   'Comment_Author': '@aadhiraarahmanexpress6154',
#   'Comment_Published': '2024-01-25T21:03:53Z'},
#  {'Comment_Id': 'UgxgHbfxOUXldW6xnfh4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '😊',
#   'Comment_Author': '@adithyaraj5028',
#   'Comment_Published': '2024-01-25T20:28:21Z'},
#  {'Comment_Id': 'UgzrVUbdGHZHfTKSNEl4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Daii mutta ponds 😂😂',
#   'Comment_Author': '@rssubash1784',
#   'Comment_Published': '2024-01-25T19:02:54Z'},
#  {'Comment_Id': 'UgwAuyB-VanCU0QGeIt4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': "Don't stop your videos. Do your best and provide best price sofas",
#   'Comment_Author': '@littleartsstudio2901',
#   'Comment_Published': '2024-01-25T18:44:36Z'},
#  {'Comment_Id': 'UgxcJq5PRGgNFnfqgwp4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sari da kutti kunja 😂😂😂',
#   'Comment_Author': '@RohithRaghavann',
#   'Comment_Published': '2024-01-25T18:01:21Z'},
#  {'Comment_Id': 'Ugxr5MYRfibciS-daDt4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'மொதல்ல உன்கிட்ட கிட்ட வாங்குன சொப்பா வ ரிப்பேர் பண்றதுக்கு help பண்ணு',
#   'Comment_Author': '@sabarisekar46',
#   'Comment_Published': '2024-01-25T17:40:52Z'},
#  {'Comment_Id': 'UgwQkDKRX0KTrwbTl994AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'வாழ்த்துக்கள் தம்பி',
#   'Comment_Author': '@Mviji-qe8qu',
#   'Comment_Published': '2024-01-25T17:40:38Z'},
#  {'Comment_Id': 'UgwhqLm_j5BJGseHkLN4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Fraud punda',
#   'Comment_Author': '@user-kb8ir1sp4x',
#   'Comment_Published': '2024-01-25T17:31:20Z'},
#  {'Comment_Id': 'UgwX58j7GU-9HYyi3NZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '👌',
#   'Comment_Author': '@Aishmonika',
#   'Comment_Published': '2024-01-25T17:27:29Z'},
#  {'Comment_Id': 'UgxRdxCHGBceuccdH954AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'நீயே ஒரு சோபா மாதிரி தாண்டா இருக்க❤❤',
#   'Comment_Author': '@vijayantenkasi2116',
#   'Comment_Published': '2024-01-25T17:10:55Z'},
#  {'Comment_Id': 'Ugxe_wOIUsBmKkwITrh4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thopa... Mutta mooditu nee vela paru',
#   'Comment_Author': '@esakppp6013',
#   'Comment_Published': '2024-01-25T16:58:22Z'},
#  {'Comment_Id': 'UgzidC-2BnryPPdNGmN4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thambi unnoda speech superda❤',
#   'Comment_Author': '@user-ne7fz9mg3q',
#   'Comment_Published': '2024-01-25T16:34:01Z'},
#  {'Comment_Id': 'UgwRErvtTh7SXlRcK_B4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Nee super 👏👏👏👏thambii',
#   'Comment_Author': '@shilmiganesh1301',
#   'Comment_Published': '2024-01-25T16:11:19Z'},
#  {'Comment_Id': 'UgyOkqRj4D5ti6Zxcqt4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'வாழ்த்துக்கள் டா தம்பி நல்லா வருவ',
#   'Comment_Author': '@sundaramoorthi1425',
#   'Comment_Published': '2024-01-25T16:01:33Z'},
#  {'Comment_Id': 'UgxJRgIHAOgdRgUgALF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Evan Nadi narambu ellam sofa dhan 😂',
#   'Comment_Author': '@rocketrahul7443',
#   'Comment_Published': '2024-01-25T15:21:35Z'},
#  {'Comment_Id': 'UgyT-PurY2zfd6lfKB14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Ni nalla varuva da thambi❤❤❤',
#   'Comment_Author': '@Battifoodvlogs',
#   'Comment_Published': '2024-01-25T15:19:04Z'},
#  {'Comment_Id': 'UgxSlOzrCw2tiGvh4Hp4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Sobakku poranthavanea😅',
#   'Comment_Author': '@peasegamer6798',
#   'Comment_Published': '2024-01-25T15:12:42Z'},
#  {'Comment_Id': 'UgzyUBp54bzzT2LE1-h4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'You do your best thambi',
#   'Comment_Author': '@sarveswarya.mahadevan1596',
#   'Comment_Published': '2024-01-25T14:50:45Z'},
#  {'Comment_Id': 'UgwCQblc2sTr5btC7DR4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Gundu paya Nala varuva da',
#   'Comment_Author': '@king_of_hell_i',
#   'Comment_Published': '2024-01-25T14:45:27Z'},
#  {'Comment_Id': 'UgzCKIcTpVfa2E90YNF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Great job! Thambi❤',
#   'Comment_Author': '@IMPOSTER-lk8ds',
#   'Comment_Published': '2024-01-25T14:40:04Z'},
#  {'Comment_Id': 'UgwgQytuhF1WrIPQmut4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'அவரு வேலை செ\u200cய்யு\u200cறது இருக்கட்டும். நீ ஏன் இப்படி அநியாயத்திற்கு கூவிக்கூவி வடை சுட்டுட்டு இருக்குற 😂😂',
#   'Comment_Author': '@AshokKumar_87',
#   'Comment_Published': '2024-01-25T14:32:19Z'},
#  {'Comment_Id': 'UgyHAuwvT8suy7Nn50h4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Neeye oru kutty shofa mari bushu bushu nu alaga iruka da thambi...ne pesarathum super ah iruku ...😂❤❤❤..All the best da thambi...🎉🎉',
#   'Comment_Author': '@nandhinis4359',
#   'Comment_Published': '2024-01-25T14:20:21Z'},
#  {'Comment_Id': 'UgwC1C1_Ok0ntd7Hs1l4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '😇😇',
#   'Comment_Author': '@mahalingam2794',
#   'Comment_Published': '2024-01-25T14:16:11Z'},
#  {'Comment_Id': 'Ugy8Kd5CYjEWh6djU6V4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Big fraud',
#   'Comment_Author': '@muskaanfathima6587',
#   'Comment_Published': '2024-01-25T14:11:29Z'},
#  {'Comment_Id': 'Ugwv1Vae4FjiuC85bGJ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Fraud',
#   'Comment_Author': '@muskaanfathima6587',
#   'Comment_Published': '2024-01-25T14:11:19Z'},
#  {'Comment_Id': 'Ugza4MENnazIy_CDjYZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Poi avaruku velai senju kudu da dai video podama',
#   'Comment_Author': '@allrounderupdate',
#   'Comment_Published': '2024-01-25T14:05:34Z'},
#  {'Comment_Id': 'Ugxhns2t5lTGdnPpqU14AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Best sales man of the decade.. ❤❤❤❤❤',
#   'Comment_Author': '@moulimathews9669',
#   'Comment_Published': '2024-01-25T13:27:54Z'},
#  {'Comment_Id': 'UgzE2xlUQnszoXXm8ZF4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Nee naasama poova',
#   'Comment_Author': '@PrajanP-ye6hq',
#   'Comment_Published': '2024-01-25T13:25:10Z'},
#  {'Comment_Id': 'UgzGDfE-glRl6kJj44t4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': '❤',
#   'Comment_Author': '@kowshic2392',
#   'Comment_Published': '2024-01-25T13:12:01Z'},
#  {'Comment_Id': 'Ugxu3SoozR-7-SsWc-54AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'வாழ்த்துக்கள்டா தம்பி.... \nஒவ்வொரு பிள்ளையும் பெற்றவர்களுக்கு உன்னை போல பொறுப்பாக நடந்து கொண்டாலே போதும்.... 🎉🎉🎉🎉',
#   'Comment_Author': '@suriyanarayan71',
#   'Comment_Published': '2024-01-25T13:04:34Z'},
#  {'Comment_Id': 'UgzQEYKyqSaJ9GMDhLp4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Enkuthodankum enkumudium',
#   'Comment_Author': '@fasarathfasaroo',
#   'Comment_Published': '2024-01-25T12:12:31Z'},
#  {'Comment_Id': 'UgyK-9OaK9VRADyih1V4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'நீ வளரும் காலம் வெகு தொலைவில் இல்லை 😂\nஏனெனில் பிகைன்வுட் சேனல் ல உண்க்காக விளம்பரங்கள் நடக்கிறது ஆர் ஜே பாலாஜி தான் உணக்காக விளம்பர மாடல்',
#   'Comment_Author': '@mdhusainhusain9558',
#   'Comment_Published': '2024-01-25T11:33:03Z'},
#  {'Comment_Id': 'UgwwGCgpK2sBP2THTm54AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': "Haters are gonna hate but ignore calmly\nNegativity எல்லாம் தள்ளி வை baby\nFocus on what you dream and don't worry மாப்பி\nPostivity உன்ன lift பண்ணும் baby",
#   'Comment_Author': '@Aspire226',
#   'Comment_Published': '2024-01-25T11:24:57Z'},
#  {'Comment_Id': 'Ugz473K3tGSjZAgrS_94AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Entrepreneur 🎉🎉🎉🎉❤',
#   'Comment_Author': '@sensuryas',
#   'Comment_Published': '2024-01-25T11:23:03Z'},
#  {'Comment_Id': 'UgxAfhIxptX3whdbWRZ4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'நீ நல்ல வருவடா குண்டு பையா நீ நல்ல வருவ❤',
#   'Comment_Author': '@venkatesan-fl1xj',
#   'Comment_Published': '2024-01-25T11:19:14Z'},
#  {'Comment_Id': 'Ugz6naKlwiITSh2ea8B4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Super thambi',
#   'Comment_Author': '@vijayalakshmi-nr3nk',
#   'Comment_Published': '2024-01-25T11:07:21Z'},
#  {'Comment_Id': 'UgwdyU8AJ_ZFf0IoDHV4AaABAg',
#   'Video_Id': 'shtXOmYiuGk',
#   'Comment_Text': 'Thambi sofala kudama urgent delivery eruku Neenga sollitan enaku terum \n\nYaaru Avan order sainjadu apdi enna pannuvan urgent delivery vangi 😂😂😂😂😂😂😂',
#   'Comment_Author': '@ransurya6084',
#   'Comment_Published': '2024-01-25T10:45:01Z'}]

# %%
def get_playlist_info(channel_id):
    All_data=[]
    next_page_token=None
    while True:
        response=youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token).execute()

        for item in response['items']:
            data=dict(Playlist_Id=item['id'],
                    Title=item['snippet']['title'],
                    Channel_Id=item['snippet']['channelId'],
                    Channel_Name=item['snippet']['channelTitle'],
                    PublishedAt=item['snippet']['publishedAt'],
                    Video_Count=item['contentDetails']['itemCount'])
            All_data.append(data)
        
        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return All_data

# %%
playlist_details=get_playlist_details('UCXPTGN7Kw1M2kXUzQCyG-zg')

# %%
len(playlist_details)
# Out:
# 20

# %%
import pymongo

# %%
import pymongo
import certifi

client = pymongo.MongoClient("mongodb+srv://ajaysuria78:1234@cluster0.siwceqi.mongodb.net/?retryWrites=true&w=majority", tlsCAFile=certifi.where())
db=client["Youtube_data"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_info(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_videos_info(vi_ids)
    com_details=get_Comment_Information(vi_ids)
   
    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,
                      "playlist_information":pl_details,
                      "video_information":vi_details,
                     "comment_information":com_details})
    return "upload success"

# %%
#UCXPTGN7Kw1M2kXUzQCyG-zg
#UCjptQL2p_BS9dCdOKXW1qWw
#UC_gXhnzeF5_XIFn4gx_bocg

# %%
channel_details("UC_gXhnzeF5_XIFn4gx_bocg")
# Out:
# 'upload success'

# %%
import mysql.connector

# %%
mydb=mysql.connector.connect(
    host='localhost',
    user='root',
    passwd="ajaysuria@070",
    auth_plugin='mysql_native_password',
    database="youtube_data")
mycursor=mydb.cursor(buffered=True)

# %%
mycursor=mydb.cursor(buffered=True)
mycursor.execute('create database if not exists youtube_data')

# %%
def channels_table():
    mydb=mysql.connector.connect(
        host='localhost',
        user='root',
        passwd="ajaysuria@070",
        auth_plugin='mysql_native_password',
        database="youtube_data")
    mycursor=mydb.cursor(buffered=True)

    drop_query='''drop table if exists channels'''
    mycursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(80) primary key,
                                                            Subscription_Count bigint,
                                                            Views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        mycursor.execute(create_query)
        mydb.commit()
    except:
        print("Channels table already created")


    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list)


    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name,
                                            Channel_Id,
                                            Subscription_Count,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscription_Count'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])
        try:
            mycursor.execute(insert_query,values)
            mydb.commit()
        except:
            print("Channel values are already inserted")

# %%
channels_table()

# %%
def playlist_table():
    mydb=mysql.connector.connect(
            host='localhost',
            user='root',
            passwd="ajaysuria@070",
            auth_plugin='mysql_native_password')
    mycursor=mydb.cursor(buffered=True)
        
    #Table creation for channels in MySql
    mycursor.execute("create database if not exists youtube_data")
    mycursor.execute("use youtube_data")
    mycursor.execute("drop table if exists playlists")
    mydb.commit()
    try:
        mycursor.execute('''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                                    Title varchar(100),
                                                                    Channel_Id varchar(100),
                                                                    Channel_Name varchar(100),
                                                                    Published_At timestamp,
                                                                    Video_Count int)''')
        mydb.commit()

    except:
        print("Error in creating table")
        
    #Extracting  playlists details from mongodb and making it to DataFrame
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db['channel_details']
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
    df1=pd.DataFrame(pl_list)

    #Pushing data to Mysql
    for index,row in df1.iterrows():
        
        row['PublishedAt'] = pd.to_datetime(row['PublishedAt']).strftime('%Y-%m-%d %H:%M:%S')
        
        insert_query='''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name,
                                            Published_At,
                                            Video_Count)
                                                                        
                                            values(%s,%s,%s,%s,%s,%s)'''
    

        values=(row['Playlist_Id'],
                                row['Title'],
                                row['Channel_Id'],
                                row['Channel_Name'],
                                row['PublishedAt'],
                                row['Video_Count'])
        try:
            mycursor.execute(insert_query,values)
            mydb.commit()
        except mysql.connector.errors.IntegrityError:
                print("Channel values already inserted")

# %%
df2
# Out:
#                        Channel_Name                Channel_Id     Video_Id  \
# 0                      Mind of Moto  UCXPTGN7Kw1M2kXUzQCyG-zg  qQ1IDsL4-wk
# 1                      Mind of Moto  UCXPTGN7Kw1M2kXUzQCyG-zg  sw9BVKR9zDQ
# 2                      Mind of Moto  UCXPTGN7Kw1M2kXUzQCyG-zg  d_Plag4xCl0
# 3                      Mind of Moto  UCXPTGN7Kw1M2kXUzQCyG-zg  dfaK99JvX0Y
# 4                      Mind of Moto  UCXPTGN7Kw1M2kXUzQCyG-zg  drHSaYO4VAo
# ..                              ...                       ...          ...
# 297  Raaj Kamal Films International  UC_gXhnzeF5_XIFn4gx_bocg  I3R4s1u85jg
# 298  Raaj Kamal Films International  UC_gXhnzeF5_XIFn4gx_bocg  cS3jODQOyxM
# 299  Raaj Kamal Films International  UC_gXhnzeF5_XIFn4gx_bocg  9IjbVncfxRg
# 300  Raaj Kamal Films International  UC_gXhnzeF5_XIFn4gx_bocg  k-85FRl-e6M
# 301  Raaj Kamal Films International  UC_gXhnzeF5_XIFn4gx_bocg  nigHNzn5zfM
#
#                                                  Title  \
# 0    Honda CB350RS Full Detailed Review || Mind of ...
# 1        Honda Dio Sports Edition 2022 || Mind of Moto
# 2    Honda CB 350 RS 2022 | Moto Shorts | Mind of M...
# 3    Honda Dio Sports Edition 2022 | Moto Shorts | ...
# 4    Royal Enfield Hunter Metro Full Detailed Revie...
# ..                                                 ...
# 297        Kamal Hassan thanking the Viewers (English)
# 298          Kamal Hassan thanking the Viewers (Tamil)
# 299  Kamal Hassan Answers R.C Shakthi | Ulaganayaga...
# 300  K VAAIMOZHI - ULAGANAYAGAN KAMAL HAASAN Introd...
# 301                   Ulaganayagan's K Vaaimozhi...!!!
#
#                                                   Tags  \
# 0    [Honda CB350 RS, Autocar India, Zigwheels, Mot...
# 1                               [Honda, Autocar India]
# 2                            [hondacb350rs, honda 350]
# 3                   [dio, honda dio, honda dio sports]
# 4          [Royal Enfield, Autocar India, Faizal Khan]
# ..                                                 ...
# 297  [kamal haasan, kvaaimozhi, k vaaimozhi, k vaai...
# 298  [k vaaimozhi, kvaaimozhi, k vaai mozhi, Kamal ...
# 299  [R C Sakthi, kamal, kamal haasan, Kamal Haasan...
# 300  [kamal haasan, kamal, ulaganayagan tube, ulaga...
# 301                                               None
#
#                                           Thumbnail  \
# 0    https://i.ytimg.com/vi/qQ1IDsL4-wk/default.jpg
# 1    https://i.ytimg.com/vi/sw9BVKR9zDQ/default.jpg
# 2    https://i.ytimg.com/vi/d_Plag4xCl0/default.jpg
# 3    https://i.ytimg.com/vi/dfaK99JvX0Y/default.jpg
# 4    https://i.ytimg.com/vi/drHSaYO4VAo/default.jpg
# ..                                              ...
# 297  https://i.ytimg.com/vi/I3R4s1u85jg/default.jpg
# 298  https://i.ytimg.com/vi/cS3jODQOyxM/default.jpg
# 299  https://i.ytimg.com/vi/9IjbVncfxRg/default.jpg
# 300  https://i.ytimg.com/vi/k-85FRl-e6M/default.jpg
# 301  https://i.ytimg.com/vi/nigHNzn5zfM/default.jpg
#
#                                            Description        Published_Date  \
# 0    The Honda CB350 RS looks like an H'ness CB350 ...  2022-08-28T09:39:00Z
# 1    Honda Motorcycle & Scooter India has introduce...  2022-08-25T10:30:17Z
# 2    #honda\n#cb350rs \n#cb350rs2022\n#rehunter350 ...  2022-08-23T16:24:43Z
# 3    #dio\n#hondadiobs6 \n#hondadio\n#diosports\n\n...  2022-08-22T14:45:02Z
# 4    The Hunter will be the most affordable model f...  2022-08-20T15:18:54Z
# ..                                                 ...                   ...
# 297  Kamal Hassan Facebook page reaches 3 Million!\...  2014-11-15T10:55:55Z
# 298  Kamal Hassan Facebook page reaches 3 Million!\...  2014-11-15T10:53:50Z
# 299  KH answers RC SHAKTHI | Ulaganayagan Tube\n\nL...  2014-11-09T14:34:01Z
# 300  K Vaaimozhi - "Kamal Vaaimozhi" Q&A With Ulaga...  2014-11-09T04:52:38Z
# 301                                                     2014-11-07T08:52:42Z
#
#      Duration  Views Likes Comments Favorite_Count Definition Caption_Status
# 0    00:12:15   3788   113       27              0         hd          false
# 1    00:08:46  19872   457       27              0         hd          false
# 2    00:00:36   1071    82       19              0         hd          false
# 3    00:00:45   2248   152       14              0         hd          false
# 4    00:10:15   7857   259       54              0         hd          false
# ..        ...    ...   ...      ...            ...        ...            ...
# 297  00:01:53  16504   161        6              0         hd          false
# 298  00:01:29  20508   323       13              0         hd          false
# 299  00:01:37  46585   493       13              0         hd          false
# 300  00:00:55  56865   538       16              0         hd          false
# 301  00:01:00  25012   401       20              0         hd          false
#
# [302 rows x 15 columns]

# %%
def videos_table():
    mydb=mysql.connector.connect(
        host='localhost',
        user='root',
        passwd="ajaysuria@070",
        auth_plugin='mysql_native_password',
        database="youtube_data")
    mycursor=mydb.cursor(buffered=True)

    drop_query='''drop table if exists videos'''
    mycursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration TIME,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50)
                                                        )'''
    mycursor.execute(create_query)
    mydb.commit()


    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=pd.DataFrame(vi_list)

    def parse_duration(duration):
        # Remove the 'PT' prefix
        duration = duration[2:]

        hours = 0
        minutes = 0
        seconds = 0

        # Extract hours
        if 'H' in duration:
            hours, duration = duration.split('H')
            hours = int(hours)

        # Extract minutes
        if 'M' in duration:
            minutes, duration = duration.split('M')
            minutes = int(minutes)

        # Extract seconds
        if 'S' in duration:
            seconds, duration = duration.split('S')
            seconds = int(seconds)

        return "{:02d}:{:02d}:{:02d}".format(hours, minutes, seconds)

    # Apply the function to the 'Duration' column
    df2['Duration'] = df2['Duration'].apply(parse_duration)


    for index,row in df2.iterrows():
        
        row['Published_Date'] = pd.to_datetime(row['Published_Date']).strftime('%Y-%m-%d %H:%M:%S')

        insert_query='''insert into videos(Channel_Name,
                                        Channel_Id,
                                        Video_Id,
                                        Title,
                                        Tags,
                                        Thumbnail,
                                        Description,
                                        Published_Date,
                                        Duration,
                                        Views,
                                        Likes,
                                        Comments,
                                        Favorite_Count,
                                        Definition,
                                        Caption_Status
                                        )

                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

        # Check if 'Tags' is a list before joining
        tags = ','.join(row['Tags']) if isinstance(row['Tags'], list) else ''

        values=(row['Channel_Name'],
        row['Channel_Id'],
        row['Video_Id'],
        row['Title'],
        tags,  # Use the joined string
        row['Thumbnail'],
        row['Description'],
        row['Published_Date'],
        row['Duration'],
        row['Views'],
        row['Likes'],
        row['Comments'],
        row['Favorite_Count'],
        row['Definition'],
        row['Caption_Status']
        )

        mycursor.execute(insert_query,values)
        mydb.commit()

# %%
def comments_table():
    mydb=mysql.connector.connect(
        host='localhost',
        user='root',
        passwd="ajaysuria@070",
        auth_plugin='mysql_native_password',
        database="youtube_data")
    mycursor=mydb.cursor(buffered=True)

    drop_query='''drop table if exists comments'''
    mycursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                        )'''
    mycursor.execute(create_query)
    mydb.commit()

    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3=pd.DataFrame(com_list)

    for index,row in df3.iterrows():
        
        row['Comment_Published'] = pd.to_datetime(row['Comment_Published']).strftime('%Y-%m-%d %H:%M:%S')

        insert_query='''insert into comments(Comment_Id,
                                            Video_Id,
                                            Comment_Text,
                                            Comment_Author,
                                            Comment_Published
                                            )

                                            values(%s,%s,%s,%s,%s)'''
        
        
        values=(row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text'],
                row['Comment_Author'],
                row['Comment_Published']
                )
        mycursor.execute(insert_query,values)
        mydb.commit()

# %%
df3.columns
# Out:
# Index(['Comment_Id', 'Video_Id', 'Comment_Text', 'Comment_Author',
#        'Comment_Published'],
#       dtype='object')

# %%
playlist_table()
# Out:
# An error occured: Not enough parameters for the SQL statement

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return"Tables Created Succesfully"

# %%
Tables=tables()

# %%
def show_channels_table():
    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():    
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db['channel_details']
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3=st.dataframe(com_list)

    return df3
